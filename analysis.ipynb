# %% [markdown]
# # **Project Name** - PhonePe Transaction Insights

# %% [markdown]
# ##### **Project Type** - Data Visualization/ Analytical Thinking
# ##### **Contribution** - Individual
# ##### **Team Number 1** - H.SaiSandeep

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Key Findings from Data Analysis:**
#
# * **Geographical Performance:**
#     * Maharashtra and Karnataka consistently lead in total transaction volume and value, respectively.
#     * Uttar Pradesh, Telangana, Maharashtra, and Madhya Pradesh show the highest year-over-year growth in transaction amounts (2021 vs. 2022), indicating expanding digital adoption in these regions.
#     * Karnataka also leads in total insurance premium collection, with other Southern states like Tamil Nadu, Kerala, and Telangana contributing significantly.
#
# * **Device Brand Insights:**
#     * Xiaomi, Vivo, Samsung, and Oppo dominate in terms of both total registered users and app opens, highlighting their strong market penetration.
#     * While high in user count, some brands like Xiaomi may exhibit slightly lower app engagement per user compared to others.
#
# * **Payment Instrument Trends:**
#     * Merchant payments account for the highest transaction *volume*, while peer-to-peer payments drive the highest *total transaction amount*, suggesting larger average values per P2P transaction.
#     * "Recharge & bill payments," "Others," and "Financial Services" instruments show considerably less activity in both count and amount.
#
# * **Overall Trends:**
#     * Both the total insurance premium count and amount exhibit a strong, consistent upward trend over time (2020 Q2 to 2024 Q4), indicating healthy growth in the insurance sector. The premium amount is growing at an accelerated rate.
#
# **Recommendations for Positive Business Impact:**
#
# * **Strategic Market Focus:** Prioritize resource allocation, marketing, and infrastructure development in high-performing and high-growth states (Karnataka, Maharashtra, Telangana, Uttar Pradesh).
# * **Optimize for Dominant Device Brands:** Ensure products and services are highly optimized for Xiaomi, Vivo, Samsung, and Oppo ecosystems to maximize user reach and engagement.
# * **Tailor Payment Instrument Strategies:** Enhance merchant payment solutions for high volume while optimizing peer-to-peer services for high-value transactions. Re-evaluate investment in less utilized payment instruments.
# * **Leverage Cross-Sector Synergies:** Capitalize on the robust growth in both digital transactions and insurance premiums by exploring integrated financial services or cross-selling opportunities.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/sandeep1297/Labmentix_week6

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem statement for the PhonePe Transaction Insights project is:
#
# With the increasing reliance on digital payment systems like PhonePe, understanding the dynamics of transactions, user engagement, and insurance-related data is crucial for improving services and targeting users effectively. This project aims to analyze and visualize aggregated values of payment categories, create maps for total values at state and district levels, and identify top-performing states, districts, and pin codes."

# %% [markdown]
# #### **Defining My Business Objective?**

# %% [markdown]
# ### Business Objectives
#
# The business objectives for the PhonePe Transaction Insights project, as detailed in the provided document, are:
#
# * **Customer Segmentation:** Identify distinct user groups based on spending habits to tailor marketing strategies.
# * **Fraud Detection:** Analyze transaction patterns to spot and prevent fraudulent activities.
# * **Geographical Insights:** Understand payment trends at state and district levels for targeted marketing.
# * **Payment Performance:** Evaluate the popularity of different payment categories for strategic investments.
# * **User Engagement:** Monitor user activity to develop strategies that enhance retention and satisfaction.
# * **Product Development:** Use data insights to inform the creation of new features and services.
# * **Insurance Insights:** Analyze insurance transaction data to improve product offerings and customer experience.
# * **Marketing Optimization:** Tailor marketing campaigns based on user behavior and transaction patterns.
# * **Trend Analysis:** Examine transaction trends over time to anticipate demand fluctuations.
# * **Competitive Benchmarking:** Compare performance against competitors to identify areas for improvement.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Uploading Dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9949eae-ed2c-4207-aacc-da5defb89a25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9949eae-ed2c-4207-aacc-da5defb89a25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Visualizing the results of SQL queries**

# %% [markdown]
# # **Chart - 1**

# %%
# Load the dataset
df = pd.read_excel('1.1 Total transaction count and amount per payment instrument across all years and quarters (2).xlsx')

# Create subplots for the two charts
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Plot 'total_transactions' by 'transaction_type'
df_transactions = df.sort_values(by='total_transactions', ascending=False)
axes[0].bar(df_transactions['transaction_type'], df_transactions['total_transactions'])
axes[0].set_title('Total Transactions by Payment Instrument')
axes[0].set_xlabel('Payment Instrument')
axes[0].set_ylabel('Total Transactions')
axes[0].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[0].set_xticklabels(df_transactions['transaction_type'], rotation=90, ha='right')

# Plot 'total_transaction_amount' by 'transaction_type'
df_amount = df.sort_values(by='total_transaction_amount', ascending=False)
axes[1].bar(df_amount['transaction_type'], df_amount['total_transaction_amount'])
axes[1].set_title('Total Transaction Amount by Payment Instrument')
axes[1].set_xlabel('Payment Instrument')
axes[1].set_ylabel('Total Transaction Amount')
axes[1].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[1].set_xticklabels(df_amount['transaction_type'], rotation=90, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-58-1466656845.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(df_transactions['transaction_type'], rotation=90, ha='right')
# /tmp/ipython-input-58-1466656845.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(df_amount['transaction_type'], rotation=90, ha='right')

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# Bar charts effectively compare different payment instruments by both transaction count and total amount, clearly showing their distinct contributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Merchant payments lead in transaction count, while peer-to-peer payments dominate in total transaction amount, indicating different average transaction values. Recharge & bill payments and other categories are significantly smaller.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Optimize platforms for high-volume merchant payments and high-value peer-to-peer transfers separately. Tailor marketing to emphasize convenience for merchants and security for P2P.
# - Explore revenue models or premium features for the high-value peer-to-peer segment.
# - The charts show current positive activity levels and distribution, not any decline or negative growth over time.

# %% [markdown]
# # **Chart - 2**

# %%
# Load the dataset
df = pd.read_excel("1.2 Quarterly transaction trend for a specific state (e.g., 'maharashtra') and payment instrument (e.g., 'Recharge & bill payments') (2).xlsx")

# Create subplots for the two charts
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Plot 'total_transactions' by 'transaction_type'
df_transactions = df.sort_values(by='total_transactions', ascending=False)
axes[0].bar(df_transactions['transaction_type'], df_transactions['total_transactions'])
axes[0].set_title('Total Transactions by Payment Instrument (e.g., Maharashtra, Recharge & bill payments)')
axes[0].set_xlabel('Payment Instrument')
axes[0].set_ylabel('Total Transactions')
axes[0].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[0].set_xticklabels(df_transactions['transaction_type'], rotation=90, ha='right')

# Plot 'total_transaction_amount' by 'transaction_type'
df_amount = df.sort_values(by='total_transaction_amount', ascending=False)
axes[1].bar(df_amount['transaction_type'], df_amount['total_transaction_amount'])
axes[1].set_title('Total Transaction Amount by Payment Instrument (e.g., Maharashtra, Recharge & bill payments)')
axes[1].set_xlabel('Payment Instrument')
axes[1].set_ylabel('Total Transaction Amount')
axes[1].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[1].set_xticklabels(df_transactions['transaction_type'], rotation=90, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-56-139258981.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(df_transactions['transaction_type'], rotation=90, ha='right')
# /tmp/ipython-input-56-139258981.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(df_transactions['transaction_type'], rotation=90, ha='right')

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing discrete payment instruments by total transactions and total amount, clearly showing their relative usage in Maharashtra for recharge and bill payments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Merchant payments overwhelmingly dominate both transaction count and amount. Peer-to-peer payments are a distant second, while recharge/bill payments, "Others," and "Financial Services" instruments show significantly less activity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Businesses should prioritize optimizing and expanding merchant payment solutions due to their high volume and value. Enhancing peer-to-peer experience can capture the second-largest segment.
# - Evaluate or reallocate resources from niche instruments (Others, Financial Services) to focus on the dominant payment types.
# - The charts show current positive activity levels; they do not indicate any decline or negative growth for any payment instrument.

# %% [markdown]
# # **Chart - 3**

# %%
# Load the dataset
df = pd.read_excel('1.3 Top 5 states by total transaction amount for a specific year (e.g., 2022) (2).xlsx')

# Sort the data by 'total_transaction_amount' in descending order
df_sorted = df.sort_values(by='total_transaction_amount', ascending=False)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_sorted['state'], df_sorted['total_transaction_amount'])
plt.title('Top 5 States by Total Transaction Amount (e.g., 2022)')
plt.xlabel('State')
plt.ylabel('Total Transaction Amount')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.savefig('top_5_states_transaction_amount.png')
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# A bar chart effectively compares and ranks the top 5 states by total transaction amount, clearly visualizing their contributions in 2022.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Telangana leads in total transaction amount, followed closely by Maharashtra and Karnataka. Southern Indian states (Telangana, Karnataka, Andhra Pradesh) show a strong concentration of high-value transactions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Businesses should strategically focus resources, marketing, and infrastructure development in high-value states like Telangana, Maharashtra, and Karnataka.
# - The dominance of Southern states suggests the need for tailored regional investment and understanding of specific drivers for high-value transactions.
# - The chart displays positive transaction amounts for the top states in 2022, providing a snapshot of performance rather than indicating any decline.

# %% [markdown]
# # **Chart - 4**

# %%
# Load the dataset
df = pd.read_excel("2.1  Number of registered users and app opens by device brand across all years and quarters (2).xlsx")

# Create subplots for the two charts
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Plot 'total_registered_users' by 'brand_name'
df_users = df.sort_values(by='total_registered_users', ascending=False)
axes[0].bar(df_users['brand_name'], df_users['total_registered_users'])
axes[0].set_title('Total Registered Users by Device Brand')
axes[0].set_xlabel('Device Brand')
axes[0].set_ylabel('Total Registered Users')
axes[0].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[0].set_xticklabels(df_users['brand_name'], rotation=90, ha='right')

# Plot 'total_app_opens' by 'brand_name'
df_opens = df.sort_values(by='total_app_opens', ascending=False)
axes[1].bar(df_opens['brand_name'], df_opens['total_app_opens'])
axes[1].set_title('Total App Opens by Device Brand')
axes[1].set_xlabel('Device Brand')
axes[1].set_ylabel('Total App Opens')
axes[1].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[1].set_xticklabels(df_opens['brand_name'], rotation=90, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-55-736863180.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(df_users['brand_name'], rotation=90, ha='right')
# /tmp/ipython-input-55-736863180.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(df_opens['brand_name'], rotation=90, ha='right')

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing discrete categories (device brands) across two key metrics: registered users and app opens, clearly showcasing dominance and rankings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Oppo and Samsung are dominant across both registered users and app opens. There's a strong correlation between user count and app activity. Xiaomi, while high in users, shows a slightly lower relative rank in app opens, hinting at potential engagement differences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - App developers should prioritize optimization and marketing for top brands like Oppo, Samsung, and Xiaomi to reach the largest user base and maximize app engagement.
# - Insights can guide partnerships with leading device manufacturers for broader reach and pre-installations.
# - Both charts show only positive counts of users and app opens, providing a snapshot of current market share and activity, not trends of decline.

# %% [markdown]
# # **Chart - 5**

# %%
# Load the dataset
df = pd.read_excel("2.2  User engagement (registered users) for a specific state (e.g., 'karnataka') by device brand in a given year (e.g., 2021) (2).xlsx")

# Sort the data by 'total_users_by_brand' in descending order
df_sorted = df.sort_values(by='total_users_by_brand', ascending=False)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_sorted['brand_name'], df_sorted['total_users_by_brand'])
plt.title('Total Registered Users by Device Brand (e.g., Karnataka, 2021)')
plt.xlabel('Device Brand')
plt.ylabel('Total Registered Users')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.savefig('user_engagement_by_brand.png')
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
#  A bar chart effectively compares and ranks device brands by total registered users in Karnataka for 2021, clearly showing market share.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Xiaomi leads significantly in registered users, followed by Vivo and Samsung. Chinese brands (Xiaomi, Vivo, Oppo, Realme, OnePlus, Huawei) collectively hold a strong dominant position in the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Businesses should optimize products and marketing for dominant brands like Xiaomi, Vivo, and Samsung to maximize user reach. This also highlights partnership opportunities with these leading manufacturers.
# - Understanding device brand popularity helps tailor app development and marketing efforts to the largest user segments.
# - This static chart presents positive user counts at a specific time and does not show any decline or negative trends for any brand.

# %% [markdown]
# # **Chart - 6**

# %%
# Load the dataset
df = pd.read_excel('3.1  Total insurance premium count and amount over time (by year and quarter) (2).xlsx')

# Combine 'year' and 'quarter' for the x-axis
df['time_period'] = df['year'].astype(str) + ' Q' + df['quarter'].astype(str)

# Create subplots for the two charts
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# Plot 'total_premium_count' over time
axes[0].plot(df['time_period'], df['total_premium_count'], marker='o')
axes[0].set_title('Total Insurance Premium Count Over Time')
axes[0].set_xlabel('Year and Quarter')
axes[0].set_ylabel('Total Premium Count')
axes[0].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[0].set_xticklabels(df['time_period'], rotation=90, ha='right')

# Plot 'total_premium_amount' over time
axes[1].plot(df['time_period'], df['total_premium_amount'], marker='o', color='orange')
axes[1].set_title('Total Insurance Premium Amount Over Time')
axes[1].set_xlabel('Year and Quarter')
axes[1].set_ylabel('Total Premium Amount')
axes[1].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[1].set_xticklabels(df['time_period'], rotation=90, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-53-2927875299.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(df['time_period'], rotation=90, ha='right')
# /tmp/ipython-input-53-2927875299.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(df['time_period'], rotation=90, ha='right')

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# Line charts are ideal for displaying time-series data, effectively showing trends and changes in total insurance premium count and amount over quarters, and allowing for easy comparison of their growth trajectories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Both premium count and amount exhibit a strong, consistent upward trend from 2020 Q2 to 2024 Q4. Notably, the premium amount is growing at an accelerated rate compared to the premium count, suggesting an increase in average policy value.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The sustained growth justifies continued investment in the insurance sector and reinforces the effectiveness of current strategies. Businesses can capitalize on the increasing average premium by focusing on higher-value products or upselling.
# - The rising premium count necessitates scaling operations and customer service to efficiently manage growing volumes.
# - Both charts show a consistent overall increase, with minor fluctuations not indicating a sustained decline or negative growth for the business.

# %% [markdown]
# # **Chart - 7**

# %%
# Load the dataset
df = pd.read_excel('3.2  Top 5 states with the highest total insurance premium amount for the latest yearquarter (2).xlsx')

# Sort the data by 'total_premium_amount' in descending order
df_sorted = df.sort_values(by='total_premium_amount', ascending=False)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_sorted['state'], df_sorted['total_premium_amount'])
plt.title('Top 5 States by Total Insurance Premium Amount (Latest Year/Quarter)')
plt.xlabel('State')
plt.ylabel('Total Insurance Premium Amount')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# Bar charts are excellent for comparing and ranking the top states by total insurance premium amount, clearly showing their relative contributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Karnataka leads significantly in insurance premiums, followed closely by Maharashtra. A strong concentration of premium collection is observed in Southern Indian states (Karnataka, Tamil Nadu, Kerala, Telangana).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Insurance companies should focus resources and tailor strategies for Karnataka and Maharashtra due to their large premium base.
# -  The dominance of Southern states suggests deeper market understanding and specialized approaches for that region are beneficial.
# -The chart only displays positive, high premium amounts, indicating successful collection, not decline.

# %% [markdown]
# # **Chart - 8**

# %%
# Load the dataset
df = pd.read_excel('4.1  States with the highest growth in transaction amount year-over-year (Example for 2021 vs 2022) (2).xlsx')

# Sort the data by 'amount_growth' in descending order
df_sorted = df.sort_values(by='amount_growth', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_sorted['state'], df_sorted['amount_growth'])
plt.title('States with the Highest Growth in Transaction Amount Year-over-Year (2021 vs 2022)')
plt.xlabel('State')
plt.ylabel('Amount Growth')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# Bar charts effectively visualize and rank states by year-over-year transaction amount growth (2021 vs. 2022), clearly showing top performers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Uttar Pradesh leads significantly in growth, followed by Telangana, Maharashtra, and Madhya Pradesh.
#
# - Growth isn't confined to traditionally dominant states, highlighting rapid adoption in emerging markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# - Prioritize strategic investments and marketing in high-growth states (e.g., UP, Telangana) to capture expanding markets.
#
# - Reallocate resources to support and accelerate growth in these booming regions for optimal ROI.
#
# Negative Growth Insights:
# - None. The chart explicitly displays only positive year-over-year growth in transaction amounts for all listed states.

# %% [markdown]
# # **Chart - 9**

# %%
# Load the dataset
df = pd.read_excel('4.2  Total transaction volume and value per state for the latest year and quarter (2).xlsx')

# Create subplots for the two charts
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

# Plot 'total_transaction_volume' by 'state'
df_volume = df.sort_values(by='total_transaction_volume', ascending=False)
axes[0].bar(df_volume['state'], df_volume['total_transaction_volume'])
axes[0].set_title('Total Transaction Volume per State (Latest Year/Quarter)')
axes[0].set_xlabel('State')
axes[0].set_ylabel('Total Transaction Volume')
axes[0].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[0].set_xticklabels(df_volume['state'], rotation=90, ha='right')

# Plot 'total_transaction_value' by 'state'
df_value = df.sort_values(by='total_transaction_value', ascending=False)
axes[1].bar(df_value['state'], df_value['total_transaction_value'])
axes[1].set_title('Total Transaction Value per State (Latest Year/Quarter)')
axes[1].set_xlabel('State')
axes[1].set_ylabel('Total Transaction Value')
axes[1].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[1].set_xticklabels(df_value['state'], rotation=90, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-54-3370168714.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(df_volume['state'], rotation=90, ha='right')
# /tmp/ipython-input-54-3370168714.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(df_value['state'], rotation=90, ha='right')

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# Bar charts were chosen for clear comparison and ranking of discrete categories (states) based on transaction volume and value, allowing for easy identification of top and bottom performers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Maharashtra dominates in transaction volume, while Karnataka leads in transaction value, indicating different average transaction sizes. States like Lakshadweep and Mizoram show significantly low activity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, insights enable targeted marketing and resource allocation in high-performing states (e.g., Maharashtra, Karnataka). Ignoring low-activity regions could lead to missed future growth opportunities and competitive disadvantage, not a direct negative growth but an opportunity cost.

# %% [markdown]
# # **Chart - 10**

# %%
# Load the dataset
df = pd.read_excel('5.1  Top 10 districts by total registered users for the latest year and quarter (2).xlsx')

# Sort the data by 'total_registered_users' in descending order
df_sorted = df.sort_values(by='total_registered_users', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_sorted['district_name'], df_sorted['total_registered_users'])
plt.title('Top 10 Districts by Total Registered Users (Latest Year/Quarter)')
plt.xlabel('District Name')
plt.ylabel('Total Registered Users')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I picked this bar chart because it shows the **Top 10 Districts by Total Registered Users (Latest Year/Quarter)**. It’s an effective visual for comparing user base concentration at the district level, helping spot where the user base is largest geographically.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Bengaluru Urban** has the highest total registered users, followed by **Pune** and **Thane**, highlighting these as digital adoption hubs.
# - Metro and tier-1 districts like **Mumbai Suburban**, **Hyderabad**, and **Chennai** also appear prominently — reinforcing that major urban areas are driving high registration volumes.
# - Emerging urban regions like **Rangareddy** and **North 24 Parganas** show significant numbers, indicating growing user penetration beyond traditional metro cities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes:
# - **Positive Impact:** This data pinpoints where the user base is concentrated — which is key for targeted campaigns, hyperlocal offers, or pilot launches for new services.
# - It also highlights **upcoming growth districts** (like Rangareddy, North 24 Parganas) where digital infrastructure investments can yield high returns.
# - There’s no immediate negative growth signal, but it shows heavy reliance on a few big metros — so diversification strategies should aim to grow smaller districts’ share to reduce overdependence.

# %% [markdown]
# # **Chart - 11**

# %%
# Load the dataset
df = pd.read_excel('5.2  State-wise average app opens per registered user (simple ratio) (2).xlsx')

# Sort the data by 'avg_app_opens_per_user' in descending order
df_sorted = df.sort_values(by='avg_app_opens_per_user', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_sorted['state'], df_sorted['avg_app_opens_per_user'])
plt.title('State-wise Average App Opens per Registered User')
plt.xlabel('State')
plt.ylabel('Average App Opens Per User')
plt.xticks(rotation=90, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I picked this bar chart to show the **State-wise Average App Opens per Registered User**. This visual helps compare how actively users engage with the app across different states — highlighting both high and low engagement areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Meghalaya**, **Arunachal Pradesh**, and **Mizoram** have the highest average app opens per user, indicating highly engaged user bases despite smaller populations.
# - Larger states like **Maharashtra**, **Tamil Nadu**, and **Delhi** have relatively lower average app opens per user, suggesting that while they may have high absolute user numbers, individual engagement is weaker.
# - Some northeastern and smaller states show disproportionately high per-user engagement — a positive sign of active adoption in these regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are valuable:
# - **Positive Impact:** High-engagement states can be used as success stories — their patterns can inform strategies for boosting engagement in larger states.
# - **Opportunity:** Low-engagement large states (like Delhi, Kerala, Tamil Nadu) represent untapped potential. Tailored user engagement campaigns (features, regional content, or incentives) could lift average opens.
# - There’s no direct sign of negative growth, but low average opens may hint at churn risks or app fatigue. Proactively addressing these areas can convert passive users to active ones, improving retention and lifetime value.

# %% [markdown]
# # **Chart - 12**

# %%
# Load the dataset
df = pd.read_excel('6.1  Insurance transaction volume (premium_count) per district for a specific year and quarter (e.g., 2022 Q3) (2).xlsx')

# Sort the data by 'total_premium_count' in descending order and select the top 10 districts
df_top_10 = df.sort_values(by='total_premium_count', ascending=False).head(10)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_top_10['district'], df_top_10['total_premium_count'])
plt.title('Top 10 Districts by Insurance Transaction Volume (e.g., 2022 Q3)')
plt.xlabel('District')
plt.ylabel('Total Premium Count')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I chose this bar chart to visualize the **Top 10 Districts by Insurance Transaction Volume** (e.g., 2022 Q3). This format makes it easy to compare how insurance transaction activity is distributed across districts and spot the strongest contributors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Bengaluru Urban District** dominates significantly with the highest premium count, more than triple that of the next district.
# - **Pune District** is second, showing strong insurance activity.
# - Districts like **Thane**, **Chennai**, **Rangareddy**, and **Mumbai Suburban** follow, but with a sharp drop from the top two.
# - The remaining districts have relatively similar volumes, showing a long tail of smaller but stable markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights will help:
# - The clear dominance of **Bengaluru Urban** suggests that the district is a key insurance hub; strategies should focus on retaining and expanding services here.
# - Districts with moderate but stable volumes (like Chennai, Hyderabad, Gurugram) can be prioritized for targeted marketing to boost their share.
# - There is no sign of negative growth, but overdependence on a single district (Bengaluru Urban) could be risky if local market dynamics change. Balancing growth across multiple districts will build resilience and broader market coverage.

# %% [markdown]
# # **Chart - 13**

# %%
# Load the dataset
df = pd.read_excel('6.2  States showing significant growth in insurance premium amount between two years (Example for 2021 vs 2022) (2).xlsx')

# Create subplots for the two charts
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

# Sort by 'growth_amount' for the first plot
df_growth_amount = df.sort_values(by='growth_amount', ascending=False)
axes[0].bar(df_growth_amount['state'], df_growth_amount['growth_amount'])
axes[0].set_title('States with Significant Growth in Insurance Premium Amount (2021 vs 2022) - Absolute Growth')
axes[0].set_xlabel('State')
axes[0].set_ylabel('Growth Amount')
axes[0].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[0].set_xticklabels(df_growth_amount['state'], rotation=90, ha='right')

# Sort by 'percentage_growth' for the second plot
df_percentage_growth = df.sort_values(by='percentage_growth', ascending=False)
axes[1].bar(df_percentage_growth['state'], df_percentage_growth['percentage_growth'], color='orange')
axes[1].set_title('States with Significant Growth in Insurance Premium Amount (2021 vs 2022) - Percentage Growth')
axes[1].set_xlabel('State')
axes[1].set_ylabel('Percentage Growth (%)')
axes[1].ticklabel_format(style='plain', axis='y') # Disable scientific notation
axes[1].set_xticklabels(df_percentage_growth['state'], rotation=90, ha='right')

plt.tight_layout()
plt.savefig('insurance_premium_growth_states.png')
plt.show()
# Out:
# /tmp/ipython-input-51-679124089.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(df_growth_amount['state'], rotation=90, ha='right')
# /tmp/ipython-input-51-679124089.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(df_percentage_growth['state'], rotation=90, ha='right')

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I chose this **dual bar chart** to show the states with significant growth in insurance premium amount between **2021 and 2022** — using both **absolute growth** (left) and **percentage growth** (right). Combining these two views helps compare not only the total value increase but also how efficiently states grew relative to their base size.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - In **absolute growth**, **Karnataka**, **Maharashtra**, and **Kerala** lead by a large margin, indicating major revenue contribution.
# - States like **Tamil Nadu** and **Telangana** also show strong absolute gains.
# - In **percentage growth**, **Kerala**, **Meghalaya**, and **Tamil Nadu** show the highest growth rates, meaning they expanded significantly compared to their previous year’s base.
# - Some smaller states or UTs (like Arunachal Pradesh, Manipur) have high percentage growth but low absolute values — signaling emerging markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can be used for positive business impact:
# - States with high **absolute growth** (e.g., Karnataka, Maharashtra) should be prioritized for retention and up-selling to maintain momentum.
# - States with **high percentage growth** but low base amounts (like Meghalaya, Arunachal Pradesh) should be explored for further expansion — indicating untapped markets with rising adoption.
# - No states show negative growth here; however, states with low growth (or not visible) might need investigation to identify barriers.
# - Balancing efforts between mature high-value markets and new high-growth regions will ensure **sustainable and diversified premium growth**.

# %% [markdown]
# # **Chart - 14**

# %%
# Load the dataset
df = pd.read_excel('7.1  Top 10 states by total transaction value for the most recent data (2).xlsx')

# Sort the data by 'total_transaction_value' in descending order
df_sorted = df.sort_values(by='total_transaction_value', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_sorted['state'], df_sorted['total_transaction_value'])
plt.title('Top 10 States by Total Transaction Value (Most Recent Data)')
plt.xlabel('State')
plt.ylabel('Total Transaction Value')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I chose this bar chart to present the **top 10 states by total transaction value (most recent data)**. A bar chart is perfect to compare the scale of transaction values across multiple states, highlighting where the biggest economic activity is happening.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Telangana** and **Karnataka** are leading with the highest total transaction values, nearly equal to each other.
# - **Maharashtra** also has very high transaction value, closely following the top two.
# - There is a clear drop from the top three to Andhra Pradesh and then a gradual decline through Rajasthan to Bihar.
# - States like **Bihar** and **Madhya Pradesh** are in the top 10 but show much lower transaction values compared to the leaders, indicating potential for growth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can enable positive business impact:
# - Focusing on **maintaining high transaction volumes** in Telangana, Karnataka, and Maharashtra is important to sustain overall business health.
# - States like Bihar and Madhya Pradesh show lower transaction values within the top 10, suggesting **untapped or under-served markets** where targeted strategies could boost adoption and spending.
# - There is no direct sign of negative growth, but heavy reliance on a few states for high-value transactions can be risky. **Diversifying and growing transaction values in more states** will make the business more resilient to local economic or regulatory shifts.

# %% [markdown]
# # **Chart - 15**

# %%
# Load the dataset
df = pd.read_excel('7.2  Top 5 districts by total transaction count in \'Maharashtra\' state for 2022 Q4 (2).xlsx')

# Sort the data by 'total_transaction_count' in descending order
df_sorted = df.sort_values(by='total_transaction_count', ascending=False)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_sorted['district_name'], df_sorted['total_transaction_count'])
plt.title('Top 5 Districts by Total Transaction Count in Maharashtra (2022 Q4)')
plt.xlabel('District Name')
plt.ylabel('Total Transaction Count')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I chose this bar chart to show the **top 5 districts by total transaction count in Maharashtra for Q4 2022**. A bar chart is effective for comparing transaction activity across districts, helping identify where user engagement is highest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Pune** has the highest transaction count, followed by **Thane** and **Mumbai Suburban**.
# - There is a sharp drop after Mumbai Suburban, with **Nagpur** and **Mumbai** having much lower transaction counts.
# - This indicates that while Mumbai is the state’s commercial capital, its transaction count here is lower than Pune and Thane for this quarter, highlighting a possible shift or concentration of digital transactions in other urban centers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help drive a positive business impact:
# - Focus can be put on **sustaining high transaction activity in Pune and Thane** through offers, new services, or loyalty programs.
# - **Mumbai’s relatively low transaction count** may indicate untapped potential or customer drop-off — targeted campaigns could help boost engagement.
# - There is no direct sign of negative growth, but the underperformance of Mumbai compared to its economic size could be a warning sign if ignored. Improving service availability, marketing, or payment ease in Mumbai can unlock more transactions and balance growth.

# %% [markdown]
# # **Chart - 16**

# %%
# Load the dataset
df = pd.read_excel('8.1  Top 10 pincodes by registered users for the latest available quarter (2).xlsx')

# Convert 'pincode' to string for proper plotting on the x-axis
df['pincode'] = df['pincode'].astype(str)

# Sort the data by 'total_registered_users' in descending order
df_sorted = df.sort_values(by='total_registered_users', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_sorted['pincode'], df_sorted['total_registered_users'])
plt.title('Top 10 Pincodes by Registered Users (Latest Available Quarter)')
plt.xlabel('Pincode')
plt.ylabel('Total Registered Users')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I chose this bar chart to display the **top 10 pincodes by total registered users for the latest available quarter**. A bar chart helps quickly compare the user base distribution at a more granular geographic level, which can reveal hyperlocal trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The pincode **201301** has the highest number of registered users, crossing 950,000.
# - The drop from the top to the 10th pincode is not very steep, showing that user distribution is more balanced compared to state-level differences.
# - Multiple pincodes have over 650,000 users, suggesting that these areas have high user penetration.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can drive positive business impact:
# - The company can **hyper-target promotions and localized campaigns** in the top pincodes to maximize engagement.
# - The near-uniform user base in the top 10 indicates good adoption but also suggests that new user growth could plateau in these areas if not supported by additional services or upgrades.
# - There is no negative growth insight directly, but reliance on limited urban pincodes may expose the business to local disruptions (e.g., regional policy changes). **Expanding into adjacent or similar high-potential pincodes** can reduce this risk and support continued growth.

# %% [markdown]
# # **Chart - 17**

# %%
# Load the dataset
df = pd.read_excel('8.2  States with the highest total registered users over all time (2).xlsx')

# Sort the data by 'total_registered_users' in descending order
df_sorted = df.sort_values(by='total_registered_users', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_sorted['state'], df_sorted['total_registered_users'])
plt.title('States with the Highest Total Registered Users (Over All Time)')
plt.xlabel('State')
plt.ylabel('Total Registered Users')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I chose this bar chart to show the **states with the highest total registered users over all time**. A bar chart clearly highlights the comparison between states, helping to identify which states have the largest user bases.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Maharashtra** has the highest total registered users by a significant margin.
# - Karnataka, Andhra Pradesh, and Uttar Pradesh also have large user bases.
# - The difference between the top state (Maharashtra) and the others is notable, indicating high user concentration.
# - States like Tamil Nadu and Gujarat are at the lower end of the top 10, showing scope for growth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can drive positive business impact:
# - Focus can be placed on **engaging and retaining users in Maharashtra**, while also ensuring service quality remains high.
# - **Expansion strategies** like regional promotions or partnerships can be designed for states with a lower user base within the top 10, like Tamil Nadu and Gujarat.
# - There is no negative growth insight in the data itself, but **over-dependence on Maharashtra** poses a risk if market conditions change or competitors become aggressive there. Balancing user growth across more states can ensure sustainable and stable expansion.

# %% [markdown]
# # **Chart - 18**

# %%
# Load the dataset
df = pd.read_excel('9.1  Top 5 districts by insurance premium count for 2021 Q2 (2).xlsx')

# Sort the data by 'premium_count' in descending order
df_sorted = df.sort_values(by='premium_count', ascending=False)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_sorted['district_name'], df_sorted['premium_count'])
plt.title('Top 5 Districts by Insurance Premium Count (2021 Q2)')
plt.xlabel('District Name')
plt.ylabel('Premium Count')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I selected this bar chart to visualize the **top 5 districts by insurance premium count for Q2 2021**. A bar chart makes it simple to compare the premium counts across districts and spot which ones contribute the most in terms of policy volume.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Bengaluru Urban** has the highest premium count by a significant margin, followed by **Pune**.
# - The drop from the top two districts to the rest is steep, indicating that these two districts are major hubs for insurance policies.
# - **Hyderabad** and **Rangareddy** have similar premium counts but much lower than Bengaluru Urban.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can drive positive business impact:
# - The company can focus on **retaining existing customers and cross-selling** in top districts like Bengaluru Urban and Pune.
# - Districts like Thane, Rangareddy, and Hyderabad show potential for growth if targeted campaigns or new products are launched there.
# - There is no immediate negative growth insight, but a heavy reliance on Bengaluru Urban could be risky if local conditions change (e.g., economic slowdown, competition). Diversifying premium counts by boosting sales in underrepresented districts will help mitigate this risk.

# %% [markdown]
# # **Chart - 19**

# %%
# Load the dataset
df = pd.read_excel('9.2  Top 10 states by total insurance premium amount for the latest year and quarter (2).xlsx')

# Sort the data by 'total_insurance_premium_amount' in descending order
df_sorted = df.sort_values(by='total_insurance_premium_amount', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
plt.bar(df_sorted['state'], df_sorted['total_insurance_premium_amount'])
plt.title('Top 10 States by Total Insurance Premium Amount (Latest Year and Quarter)')
plt.xlabel('State')
plt.ylabel('Total Insurance Premium Amount')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.ticklabel_format(style='plain', axis='y') # Disable scientific notation for y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did I pick the specific chart?

# %% [markdown]
# I chose this bar chart to easily compare the **top 10 states by total insurance premium amount** in the latest year and quarter. A bar chart is ideal for showing discrete categories (states) with their corresponding values, making it simple to spot the top contributors at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Karnataka** and **Maharashtra** have significantly higher total insurance premium amounts compared to other states.
# - The top two states contribute a large portion of the total premium, indicating regional concentration.
# - States like Rajasthan and Haryana have relatively lower premium amounts within the top 10, showing a possible opportunity for growth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can drive positive business impact:
# - Insurers can **focus on retaining and expanding services** in high-value states like Karnataka and Maharashtra.
# - They can also **design targeted marketing or new products** for lower-contributing states to increase market share.
# - There is no direct indication of negative growth. However, the **over-dependence on a few states** could pose a risk if economic or regulatory conditions change in those regions. Diversifying the premium base across more states will mitigate this risk and promote stable long-term growth.

# %% [markdown]
# # 📊 **Comprehensive Recommendations from Data Insights**
#
# ---
#
# ## ✅ 1. Strategic Focus on High-Performing States
#
# - **Prioritize Karnataka, Maharashtra, Telangana, and Uttar Pradesh:**
#   Allocate significant resources (marketing, sales, infrastructure, localized product offerings) to further penetrate and consolidate market share in these leading states.
#
# - **Understand Regional Nuances:**
#   Invest in localized market research, especially in Southern India, to understand specific drivers for digital adoption and insurance uptake, informing tailored strategies.
#
# - **Capitalize on Growth Areas (UP, MP, Rajasthan, Bihar):**
#   Make early and strategic investments in these high-growth states to secure future market leadership as digital adoption rapidly expands.
#
# ---
#
# ## ✅ 2. Optimize for Dominant Device Brands
#
# - **Prioritize Xiaomi, Vivo, Samsung, and Oppo:**
#   Ensure all digital products and services are highly optimized for these Android ecosystems, including rigorous testing and tailored UI/UX design.
#
# - **Analyze Engagement Discrepancies:**
#   Investigate factors contributing to potentially lower app opens on certain high-user brands (e.g., Xiaomi) to identify opportunities for boosting engagement through device-specific features.
#
# ---
#
# ## ✅ 3. Tailor Strategies by Payment Instrument
#
# - **Enhance Merchant Payment Solutions:**
#   Continuously improve speed, reliability, and ease of use for high-volume merchant transactions, focusing on onboarding more merchants.
#
# - **Focus on High-Value Peer-to-Peer:**
#   Cater to larger P2P transfers with features like increased security, higher limits, and instant settlements, potentially exploring premium services for this segment.
#
# - **Re-evaluate Niche Instruments:**
#   Re-assess investment in low-contribution categories ("Others", "Financial Services"), potentially reallocating resources to dominant payment types or truly innovative solutions.
#
# ---
#
# ## ✅ 4. Leverage Cross-Sector Insights
#
# - **Insurance & Digital Payments Synergy:**
#   Explore partnerships between digital payment platforms and insurance providers to offer seamless premium payments or embedded insurance products, especially given the strong growth in both sectors.
#
# - **Data-Driven Product Development:**
#   Continuously analyze trends (e.g., increasing average transaction value) to inform new product development, such as premium services or features leveraging popular device brand capabilities.
#
# ---
#
# ## ✅ 5. Expand Insurance Products in High Potential States
#
# - **Focus States:** Karnataka, Kerala, Tamil Nadu, Meghalaya (high insurance premium growth)
# - **Action:** Launch innovative insurance products and awareness drives tailored to local needs.
#
# ---
#
# ## ✅ 6. Hyperlocal Engagement in Top Pincodes
#
# - **Top Pincodes:** 201301, 421302, 110059, 500072
# - **Action:** Run neighborhood-specific offers, cashback, and loyalty campaigns to deepen penetration.
#
# ---
#
# ## ✅ 7. Lift App Opens in Low-Engagement States
#
# - **Low Usage States:** Delhi, Chandigarh, Kerala
# - **Action:** Boost app opens with push notifications, referral incentives, or region-specific digital campaigns.
#
# ---
#
# ## ✅ 8. Strengthen Merchant & Consumer Ecosystem
#
# - **Leading Districts:** Bengaluru Urban, Pune, Thane
# - **Action:** Build more merchant partnerships, run local market activation events, and push premium services.
#
# ---
#
# ## 🚀 **Key Takeaway**
# Combine high-performing regions, device-specific optimizations, innovative payment features, and cross-sector synergies to expand reach, boost user engagement, and unlock sustainable growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of transaction volumes, insurance premiums, user engagement, device trends, and geographical patterns reveals clear strengths and growth opportunities for the business.
#
# Key insights show that:
# - A few states and districts (e.g., Karnataka, Maharashtra, Bengaluru Urban, Pune) contribute disproportionately to transactions, users, and premiums.
# - There are emerging high-growth pockets in states like UP, MP, Rajasthan, Bihar, and select pincodes and districts, indicating future market potential.
# - Engagement varies significantly across device brands and regions, highlighting the need for tailored user retention and product strategies.
# - Insurance transactions are growing rapidly in specific regions, offering scope for bundled financial services.
#
# **Recommendations were developed to:**
# - Double down on high-performing regions while diversifying into underpenetrated areas.
# - Optimize products for dominant device brands.
# - Strengthen merchant and P2P payment segments.
# - Leverage cross-sector synergies between digital payments and insurance.
# - Target low-engagement regions with tailored campaigns to lift repeat usage.
#
# Most business objectives — including segmentation, trend analysis, user engagement, payment performance, insurance improvement, and marketing optimization — have been directly addressed. Remaining areas like **fraud detection** and **competitive benchmarking** can be tackled with focused next steps.
#
# ✅ **Overall**, the insights and action plan provide a strong foundation to scale sustainably, unlock untapped markets, increase customer lifetime value, and strengthen the company’s competitive position in the digital payments and insurance ecosystem.
